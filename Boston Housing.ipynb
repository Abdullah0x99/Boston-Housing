# %%
import pandas as pd
import seaborn
import sklearn
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("HousingData.csv")

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
data.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
mean_value = data["CRIM"].mean()
print(mean_value)

data["CRIM"].fillna(mean_value, inplace=True)
# Out:
# 3.6118739711934156

# %%
mean_value = data["ZN"].mean()
print(mean_value)

data["ZN"].fillna(mean_value, inplace=True)
# Out:
# 11.2119341563786

# %%
mean_value = data["INDUS"].mean()
print(mean_value)

data["INDUS"].fillna(mean_value, inplace=True)
# Out:
# 11.083991769547332

# %%
mean_value = data["CHAS"].mean()
print(mean_value)

data["CHAS"].fillna(mean_value, inplace=True)
# Out:
# 0.06995884773662552

# %%
mean_value = data["AGE"].mean()
print(mean_value)

data["AGE"].fillna(mean_value, inplace=True)
# Out:
# 68.51851851851852

# %%
mean_value = data["LSTAT"].mean()
print(mean_value)

data["LSTAT"].fillna(mean_value, inplace=True)
# Out:
# 12.715432098765435

# %%
data.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
cat_features = {
    "CRIM",
    "ZN",
    "INDUS",
    "CHAS",
    "NOX",
    "RM",
    "AGE",
    "DIS",
    "RAD",
    "TAX",
    "PTRATIO",
    "B",
    "LSTAT",
    "MEDV",
}
for cat_feature in cat_features:
    print(cat_feature, data[cat_feature].unique(), sep=":")
    print("#"*50)
# Out:
# CHAS:[0.         0.06995885 1.        ]
# ##################################################
# INDUS:[ 2.31        7.07        2.18        7.87        8.14        5.96
#  11.08399177  2.95        6.91        5.64        4.          1.22
#   0.74        1.32        5.13        1.38        3.37        6.07
#  10.81       12.83        4.86        4.49        3.41       15.04
#   2.89        8.56       10.01       25.65       21.89       19.58
#   4.05        2.46        3.44        2.93        0.46        1.52
#   1.47        2.03        2.68       10.59       13.89        6.2
#   4.93        5.86        3.64        3.75        3.97        6.96
#   6.41        3.33        1.21        2.97        2.25        1.76
#   5.32        4.95       13.92        2.24        6.09        9.9
#   7.38        3.24        6.06        5.19        1.89        3.78
#   4.39        4.15        2.01        1.25        1.69        2.02
#   1.91       18.1        27.74        9.69       11.93      ]
# ...

# %%
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B      LSTAT  MEDV
# 0  396.90   4.980000  24.0
# 1  396.90   9.140000  21.6
# 2  392.83   4.030000  34.7
# 3  394.63   2.940000  33.4
# 4  396.90  12.715432  36.2

# %%
y = data["MEDV"]
x = data.drop("MEDV", axis=1)
print(type(x))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)

# %%
x_train.shape
# Out:
# (354, 13)

# %%
x_test
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD  TAX  \
# 395   8.71675   0.0  18.10   0.0  0.693  6.471   98.8  1.7257   24  666
# 414  45.74610   0.0  18.10   0.0  0.693  4.519  100.0  1.6582   24  666
# 98    0.08187   0.0   2.89   0.0  0.445  7.820   36.9  3.4952    2  276
# 421   7.02259   0.0  18.10   0.0  0.718  6.006   95.3  1.8746   24  666
# 28    0.77299   0.0   8.14   0.0  0.538  6.495   94.4  4.4547    4  307
# ..        ...   ...    ...   ...    ...    ...    ...     ...  ...  ...
# 300   0.04417  70.0   2.24   0.0  0.400  6.871   47.4  7.8278    5  358
# 289   0.04297  52.5   5.32   0.0  0.405  6.565   22.9  7.3172    6  293
# 440  22.05110   0.0  18.10   0.0  0.740  5.818   92.4  1.8662   24  666
# 169   2.44953   0.0  19.58   0.0  0.605  6.402   95.2  2.2625    5  403
# 10    0.22489  12.5   7.87   0.0  0.524  6.377   94.3  6.3467    5  311
#
#      PTRATIO       B      LSTAT
# 395     20.2  391.98  17.120000
# 414     20.2   88.27  36.980000
# ...

# %%
y_test.shape
# Out:
# (152,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3)
# Out:
# LinearRegression()

# %%
reg.predict(x_test)
# Out:
# array([20.52324231, -5.31809498, 35.51128421, 18.1937796 , 19.76627844,
#        25.20235157, 20.13849191, 14.09745072, 18.00278287, 14.1620014 ,
#        22.03714795, 40.6556708 ,  0.44549178, 24.97571764, 23.51800477,
#         9.06137413, 21.05316937, 12.82153415, 31.121177  , 13.49903463,
#        34.56538273, 20.26885774, 40.82379738, 28.92861918, 11.99950014,
#        18.19550649, 31.53738086, 23.45514606, 35.78985682, 15.92429213,
#        24.22765535, 16.39684019,  5.73909962, 15.31971222, 19.57337497,
#        19.50043784, 22.9751529 , 33.27709576, 37.26343882, 25.40038878,
#        31.44072269, 40.76703328, 39.10144548, 21.05223154, 16.05851407,
#        27.09959233, 27.41142673, 24.90062753, 25.08465399,  0.21943228,
#        34.01525067, 14.24528908, 24.47186852,  6.00631744, 19.57147985,
#        21.26812068, 22.10068511, 22.57098281, 16.47611871, 32.34269793,
#        15.58403622, 26.72434251, 23.27688855, 17.77634547, 19.85053881,
# ...

# %%
from sklearn.metrics import mean_absolute_error

y_pred = reg.predict(x_test)

print("MAE", mean_absolute_error(y_test,y_pred))
# Out:
# MAE 3.7695501643132183

# %%
from sklearn.ensemble import RandomForestRegressor

rfr_reg = RandomForestRegressor()
rfr_reg.fit(x_train, y_train)
y_pred = rfr_reg.predict(x_test)
print ("MAE", mean_absolute_error(y_test,y_pred))
# Out:
# MAE 2.4365000000000006
